# %% [markdown]
# # Python ETL & PostgreSQL Workshop
#
# ## Learning Objectives
#
# - Connect Python to PostgreSQL
# - Extract data using SQL
# - Load SQL data into pandas
# - Transform data using pandas
# - Export data to CSV
# - Understand relational databases

# %% [markdown]
# # Step 1 — Install Packages

# %%
import sys
# !{sys.executable} -m pip install sqlalchemy pandas psycopg2-binary matplotlib seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 6.9 MB/s eta 0:00:00a 0:00:01
# ...

# %% [markdown]
# # Step 2 — Import Libraries

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, URL, text

# %% [markdown]
# # Step 3 — Read Environment Variables

# %%
postgres_username = os.getenv("POSTGRES_USER")
postgres_password = os.getenv("POSTGRES_PASSWORD")
postgres_database = os.getenv("POSTGRES_DB")
postgres_host = os.getenv("POSTGRES_HOST", "postgres")
postgres_port = os.getenv("POSTGRES_PORT", "5432")

print(postgres_database)
# Out:
# multiverses

# %% [markdown]
# # Step 4 — Create Database Connection

# %%
conn_string = URL.create(
    "postgresql+psycopg2",
    username=postgres_username,
    password=postgres_password,
    host=postgres_host,
    port=postgres_port,
    database=postgres_database
)

engine = create_engine(conn_string)
engine
# Out:
# Engine(postgresql+psycopg2://multiverses:***@postgres:5432/multiverses)

# %% [markdown]
# # Step 5 — Test Connection

# %%
with engine.connect() as conn:
    print(conn)

# %% [markdown]
# # Step 6 — Extract Data from PostgreSQL

# %%
from sqlalchemy import text

with engine.connect() as conn:

    result = conn.execute(text("""

        SELECT table_schema, table_name
        FROM information_schema.tables
        WHERE table_type = 'BASE TABLE'
        AND table_schema='car_schema'
        ORDER BY table_schema, table_name;

    """))

    tables = result.fetchall()

tables
# Out:
# [('car_schema', 'car_characteristics'),
#  ('car_schema', 'car_supplier'),
#  ('car_schema', 'customer'),
#  ('car_schema', 'repair_statuses'),
#  ('car_schema', 'sale'),
#  ('car_schema', 'sale_car'),
#  ('car_schema', 'sale_customer'),
#  ('car_schema', 'suppliers'),
#  ('car_schema', 'tech_characteristics')]

# %% [markdown]
# # Step 7 — SELECT From a Table

# %%
with engine.connect() as conn:

    result = conn.execute(text("SELECT * FROM car_schema.sale_car"))

    df_sales = result.mappings().all()


df_sales = pd.DataFrame(df_sales)
print(df_sales.head(20))
# Out:
#        car_id sale_id
# 0   EV8712022   S1140
# 1   EV7992020   S1810
# 2   EV1212018   S2651
# 3   EV1682018   S7636
# 4   EV2632018   S8741
# 5   EV8842021   S6972
# 6   EV1922016   S6726
# 7   EV1202017   S7032
# 8   EV6522021   S1810
# 9   EV1562018   S4220
# 10  EV1532022   S6641
# 11  EV6972021   S1702
# 12  EV9422020   S6823
# 13  EV0922022   S6539
# 14  EV7082019   S1810
# 15  EV6432018   S9337
# 16  EV5792021   S6732
# 17  EV4252017   S3370
# 18  EV0282022   S6703
# 19  EV5542022   S0223

# %% [markdown]
# # Step 8 — Transform Data

# %%
with engine.connect() as conn:

    result = conn.execute(text("SELECT * FROM car_schema.car_characteristics;"))
    df = result.mappings().all()
    df = pd.DataFrame(df)

df.head()
# Out:
#       car_id  model country  doors  year    carbody steering_wheel      price  \
# 0  EV0832021   EVDF      UK      5  2021  Hatchback           Left   60000.00
# 1  EV3572022  EVADF      UK      3  2022      Sedan           Left  110000.00
# 2  EV8712022   EVDF     USA      5  2022        SUV          Right   60000.00
# 3  EV7992020  EVADF      UK      3  2020        SUV          Right  110000.00
# 4  EV1212018   EVDF      UK      3  2018  Hatchback           Left   60000.00
#
#   repair_status_id last_service_date
# 0             None              None
# 1             None              None
# 2             None              None
# 3             None              None
# 4             None              None

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df.groupby("carbody")["price"].mean().sort_values().plot(

    kind="barh",

    figsize=(7,4),

    title="Average Price by Body Type"

)

plt.xlabel("Average Price")

plt.show()

df.groupby("year")["price"].mean().sort_index().plot(
    kind="line",
    marker="o",
    figsize=(8,4),
    title="Average Car Price by Year"
)

plt.ylabel("Average Price")

plt.show()

# %% [markdown]
# # Step 9 — Export Data

# %%
df.to_csv('export.csv', index=False)
print('CSV exported ✔')
# Out:
# CSV exported ✔

# %% [markdown]
# # Step 10 — Database Structure

# %%
from sqlalchemy import MetaData

metadata = MetaData()
metadata.reflect(bind=engine)

print(metadata.tables.keys())
# Out:
# dict_keys([])

# %% [markdown]
# # Final Summary
#
# - Python connects to PostgreSQL via SQLAlchemy
# - Docker handles networking via service names
# - pandas is used for transformation
# - ETL = Extract, Transform, Load
